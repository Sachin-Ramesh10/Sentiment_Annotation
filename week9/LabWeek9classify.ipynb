# %%
# Classification tasks with different types of features
>>> import nltk

# %%
# classify part of speech based on sentence context
>>> from nltk.corpus import brown

# %%
# define features for the "i"th word in the sentence, including three types of suffix 
#     and one pre-word
# the pos features function takes the sentence of untagged words and the index of a word i
#   it creates features for word i, including the previous word i-1
def pos_features(sentence, i):    
    features = {"suffix(1)": sentence[i][-1:],
		    "suffix(2)": sentence[i][-2:],
		    "suffix(3)": sentence[i][-3:]}
    if i == 0:
        features["prev-word"] = "<START>"
    else:
        features["prev-word"] = sentence[i-1]
    return features

# %%
# look at features of a specific word in a specific sentence
# first sentence of brown corpus
sentence0 = brown.sents()[0]
print(sentence0)
# word 8 of sentence 0
sentence0[8]
# Out:
# [u'The', u'Fulton', u'County', u'Grand', u'Jury', u'said', u'Friday', u'an', u'investigation', u'of', u"Atlanta's", u'recent', u'primary', u'election', u'produced', u'``', u'no', u'evidence', u"''", u'that', u'any', u'irregularities', u'took', u'place', u'.']
# u'investigation'

# %%
# pos features of the word 8 
pos_features(sentence0, 8)
# Out:
# {'prev-word': u'an',
#  'suffix(1)': u'n',
#  'suffix(2)': u'on',
#  'suffix(3)': u'ion'}

# %%
# get the POS tagged sentences with categories of news
tagged_sents = brown.tagged_sents(categories='news')
tag_sent0 = tagged_sents[0]
print(tag_sent0)
# Out:
# [(u'The', u'AT'), (u'Fulton', u'NP-TL'), (u'County', u'NN-TL'), (u'Grand', u'JJ-TL'), (u'Jury', u'NN-TL'), (u'said', u'VBD'), (u'Friday', u'NR'), (u'an', u'AT'), (u'investigation', u'NN'), (u'of', u'IN'), (u"Atlanta's", u'NP$'), (u'recent', u'JJ'), (u'primary', u'NN'), (u'election', u'NN'), (u'produced', u'VBD'), (u'``', u'``'), (u'no', u'AT'), (u'evidence', u'NN'), (u"''", u"''"), (u'that', u'CS'), (u'any', u'DTI'), (u'irregularities', u'NNS'), (u'took', u'VBD'), (u'place', u'NN'), (u'.', u'.')]

# %%
# the function nltk.tag.untag will take the tags off
print(nltk.tag.untag(tag_sent0))
# Out:
# [u'The', u'Fulton', u'County', u'Grand', u'Jury', u'said', u'Friday', u'an', u'investigation', u'of', u"Atlanta's", u'recent', u'primary', u'election', u'produced', u'``', u'no', u'evidence', u"''", u'that', u'any', u'irregularities', u'took', u'place', u'.']

# %%
# the python enumerate function generates an index number for each item in a list
for i,(word,tag) in enumerate(tag_sent0):
    print (i, word, tag)
# Out:
# (0, u'The', u'AT')
# (1, u'Fulton', u'NP-TL')
# (2, u'County', u'NN-TL')
# (3, u'Grand', u'JJ-TL')
# (4, u'Jury', u'NN-TL')
# (5, u'said', u'VBD')
# (6, u'Friday', u'NR')
# (7, u'an', u'AT')
# (8, u'investigation', u'NN')
# (9, u'of', u'IN')
# (10, u"Atlanta's", u'NP$')
# (11, u'recent', u'JJ')
# (12, u'primary', u'NN')
# (13, u'election', u'NN')
# (14, u'produced', u'VBD')
# (15, u'``', u'``')
# (16, u'no', u'AT')
# (17, u'evidence', u'NN')
# (18, u"''", u"''")
# (19, u'that', u'CS')
# (20, u'any', u'DTI')
# (21, u'irregularities', u'NNS')
# (22, u'took', u'VBD')
# (23, u'place', u'NN')
# (24, u'.', u'.')

# %%
# get feature sets of words appearing in the corpus, from untagged sentences.
# and then get their tags from corresponding tagged sentence
# use the Python function enumerate to pair the index numbers with sentence words 
#   for the pos features function
featuresets = []
for tagged_sent in tagged_sents:
	untagged_sent = nltk.tag.untag(tagged_sent)
	for i, (word, tag) in enumerate(tagged_sent):
		featuresets.append( (pos_features(untagged_sent, i), tag) )

# %%
# look at the feature sets of the first 10 words
for f in featuresets[:10]:
	print (f)
# Out:
# ({'suffix(3)': u'The', 'prev-word': '<START>', 'suffix(2)': u'he', 'suffix(1)': u'e'}, u'AT')
# ({'suffix(3)': u'ton', 'prev-word': u'The', 'suffix(2)': u'on', 'suffix(1)': u'n'}, u'NP-TL')
# ({'suffix(3)': u'nty', 'prev-word': u'Fulton', 'suffix(2)': u'ty', 'suffix(1)': u'y'}, u'NN-TL')
# ({'suffix(3)': u'and', 'prev-word': u'County', 'suffix(2)': u'nd', 'suffix(1)': u'd'}, u'JJ-TL')
# ({'suffix(3)': u'ury', 'prev-word': u'Grand', 'suffix(2)': u'ry', 'suffix(1)': u'y'}, u'NN-TL')
# ({'suffix(3)': u'aid', 'prev-word': u'Jury', 'suffix(2)': u'id', 'suffix(1)': u'd'}, u'VBD')
# ({'suffix(3)': u'day', 'prev-word': u'said', 'suffix(2)': u'ay', 'suffix(1)': u'y'}, u'NR')
# ({'suffix(3)': u'an', 'prev-word': u'Friday', 'suffix(2)': u'an', 'suffix(1)': u'n'}, u'AT')
# ({'suffix(3)': u'ion', 'prev-word': u'an', 'suffix(2)': u'on', 'suffix(1)': u'n'}, u'NN')
# ({'suffix(3)': u'of', 'prev-word': u'investigation', 'suffix(2)': u'of', 'suffix(1)': u'f'}, u'IN')

# %%
# using naive Bayesian as classifier
# split data into a training set and a test set, using a 90%/10% split
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]
print(len(train_set))
print(len(test_set))
# Out:
# 90499
# 10055

# %%
# train classifier on the training set
classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy (this will take a little while)
nltk.classify.accuracy(classifier, test_set)
# the result is reasonable for POS features without the previous tag
# Out:
# 0.7891596220785678

# %%
### sentence segmentation
sents = nltk.corpus.treebank_raw.sents()
len(sents)
for sent in sents[:7]:
    print (sent)
# Out:
# [u'.', u'START']
# [u'Pierre', u'Vinken', u',', u'61', u'years', u'old', u',', u'will', u'join', u'the', u'board', u'as', u'a', u'nonexecutive', u'director', u'Nov', u'.', u'29', u'.']
# [u'Mr', u'.', u'Vinken', u'is', u'chairman', u'of', u'Elsevier', u'N', u'.', u'V', u'.,', u'the', u'Dutch', u'publishing', u'group', u'.']
# [u'.', u'START']
# [u'Rudolph', u'Agnew', u',', u'55', u'years', u'old', u'and', u'former', u'chairman', u'of', u'Consolidated', u'Gold', u'Fields', u'PLC', u',', u'was', u'named', u'a', u'nonexecutive', u'director', u'of', u'this', u'British', u'industrial', u'conglomerate', u'.']
# [u'.', u'START']
# [u'A', u'form', u'of', u'asbestos', u'once', u'used', u'to', u'make', u'Kent', u'cigarette', u'filters', u'has', u'caused', u'a', u'high', u'percentage', u'of', u'cancer', u'deaths', u'among', u'a', u'group', u'of', u'workers', u'exposed', u'to', u'it', u'more', u'than', u'30', u'years', u'ago', u',', u'researchers', u'reported', u'.']

# %%
# initialize an empty token list, an empty boundaries set and offset as the integer 0
tokens = [ ]
boundaries = set()
offset = 0
# make a list of tokens with sentence boundaries
#   the offset is set to the index of a sentence boundary
for sent in nltk.corpus.treebank_raw.sents():
      tokens.extend(sent)
      offset += len(sent)
      boundaries.add(offset - 1)

# %%
# look at tokens and boundaries
print(tokens[:40])
print(len(boundaries))
print(0 in boundaries)
print(1 in boundaries)
print(19 in boundaries)
print(20 in boundaries)
for num, tok in enumerate(tokens[:40]):
     print (num, tok, '\t', num in boundaries)
# Out:
# [u'.', u'START', u'Pierre', u'Vinken', u',', u'61', u'years', u'old', u',', u'will', u'join', u'the', u'board', u'as', u'a', u'nonexecutive', u'director', u'Nov', u'.', u'29', u'.', u'Mr', u'.', u'Vinken', u'is', u'chairman', u'of', u'Elsevier', u'N', u'.', u'V', u'.,', u'the', u'Dutch', u'publishing', u'group', u'.', u'.', u'START', u'Rudolph']
# 4193
# False
# True
# False
# True
# (0, u'.', '\t', False)
# (1, u'START', '\t', True)
# (2, u'Pierre', '\t', False)
# (3, u'Vinken', '\t', False)
# (4, u',', '\t', False)
# (5, u'61', '\t', False)
# (6, u'years', '\t', False)
# (7, u'old', '\t', False)
# (8, u',', '\t', False)
# (9, u'will', '\t', False)
# (10, u'join', '\t', False)
# (11, u'the', '\t', False)
# (12, u'board', '\t', False)
# (13, u'as', '\t', False)
# (14, u'a', '\t', False)
# (15, u'nonexecutive', '\t', False)
# (16, u'director', '\t', False)
# (17, u'Nov', '\t', False)
# (18, u'.', '\t', False)
# (19, u'29', '\t', False)
# (20, u'.', '\t', True)
# (21, u'Mr', '\t', False)
# (22, u'.', '\t', False)
# (23, u'Vinken', '\t', False)
# (24, u'is', '\t', False)
# (25, u'chairman', '\t', False)
# (26, u'of', '\t', False)
# (27, u'Elsevier', '\t', False)
# (28, u'N', '\t', False)
# (29, u'.', '\t', False)
# (30, u'V', '\t', False)
# (31, u'.,', '\t', False)
# (32, u'the', '\t', False)
# (33, u'Dutch', '\t', False)
# (34, u'publishing', '\t', False)
# (35, u'group', '\t', False)
# (36, u'.', '\t', True)
# (37, u'.', '\t', False)
# (38, u'START', '\t', True)
# (39, u'Rudolph', '\t', False)

# %%
# feature extraction function
# token is a list of words and we get the features of the token at offset i
def punct_features(tokens, i):
    return {'next-word-capitalized': tokens[i+1][0].isupper(),
        'prevword': tokens[i-1].lower(),
        'punct': tokens[i],
        'prev-word-is-one-char': len(tokens[i-1]) == 1}

# %%
# feature dictionary for the period at index 20
print(tokens[20])
punct_features(tokens,20)
# Out:
# .
# {'next-word-capitalized': True,
#  'prev-word-is-one-char': False,
#  'prevword': u'29',
#  'punct': u'.'}

# %%
# Define featuresets of all candidate punctuation
#  (read the list comprehension "outside-in")
Sfeaturesets = [(punct_features(tokens, i), (i in boundaries))
      for i in range(1, len(tokens) - 1)
      if tokens[i] in '.?!']

# %%
# look at the feature sets of the first 10 punctuation symbols
for sf in Sfeaturesets[:10]:
	print (sf)
# Out:
# ({'next-word-capitalized': False, 'punct': u'.', 'prev-word-is-one-char': False, 'prevword': u'nov'}, False)
# ({'next-word-capitalized': True, 'punct': u'.', 'prev-word-is-one-char': False, 'prevword': u'29'}, True)
# ({'next-word-capitalized': True, 'punct': u'.', 'prev-word-is-one-char': False, 'prevword': u'mr'}, False)
# ({'next-word-capitalized': True, 'punct': u'.', 'prev-word-is-one-char': True, 'prevword': u'n'}, False)
# ({'next-word-capitalized': False, 'punct': u'.', 'prev-word-is-one-char': False, 'prevword': u'group'}, True)
# ({'next-word-capitalized': True, 'punct': u'.', 'prev-word-is-one-char': True, 'prevword': u'.'}, False)
# ({'next-word-capitalized': False, 'punct': u'.', 'prev-word-is-one-char': False, 'prevword': u'conglomerate'}, True)
# ({'next-word-capitalized': True, 'punct': u'.', 'prev-word-is-one-char': True, 'prevword': u'.'}, False)
# ({'next-word-capitalized': True, 'punct': u'.', 'prev-word-is-one-char': False, 'prevword': u'reported'}, True)
# ({'next-word-capitalized': True, 'punct': u'.', 'prev-word-is-one-char': False, 'prevword': u'said'}, True)

# %%
# separate into training and test sets with a 90/10 split
size = int(len(Sfeaturesets) * 0.1)
size
# Out:
# 594

# %%
Strain_set, Stest_set = Sfeaturesets[size:], Sfeaturesets[:size]
Sclassifier = nltk.NaiveBayesClassifier.train(Strain_set)
nltk.classify.accuracy(Sclassifier, Stest_set)
# Out:
# 0.936026936026936

# %%
# define function to use the trained classifier to label sentences
def segment_sentences(words):
      start = 0
      sents = []
      for i, word in enumerate(words):
          if word in '.?!' and Sclassifier.classify(punct_features(words, i)) == True:
              sents.append(words[start:i+1])
              start = i+1
      if start < len(words):
          sents.append(words[start:])
      return sents

# %%
# try it out on a subset of the tokens from the treebank
print(len(tokens))
print(tokens[:50])

tinytokens = tokens[:1000]
for s in segment_sentences(tinytokens):
    print (s)
# Out:
# 101797
# [u'.', u'START', u'Pierre', u'Vinken', u',', u'61', u'years', u'old', u',', u'will', u'join', u'the', u'board', u'as', u'a', u'nonexecutive', u'director', u'Nov', u'.', u'29', u'.', u'Mr', u'.', u'Vinken', u'is', u'chairman', u'of', u'Elsevier', u'N', u'.', u'V', u'.,', u'the', u'Dutch', u'publishing', u'group', u'.', u'.', u'START', u'Rudolph', u'Agnew', u',', u'55', u'years', u'old', u'and', u'former', u'chairman', u'of', u'Consolidated']
# [u'.']
# [u'START', u'Pierre', u'Vinken', u',', u'61', u'years', u'old', u',', u'will', u'join', u'the', u'board', u'as', u'a', u'nonexecutive', u'director', u'Nov', u'.', u'29', u'.', u'Mr', u'.', u'Vinken', u'is', u'chairman', u'of', u'Elsevier', u'N', u'.', u'V', u'.,', u'the', u'Dutch', u'publishing', u'group', u'.']
# [u'.', u'START', u'Rudolph', u'Agnew', u',', u'55', u'years', u'old', u'and', u'former', u'chairman', u'of', u'Consolidated', u'Gold', u'Fields', u'PLC', u',', u'was', u'named', u'a', u'nonexecutive', u'director', u'of', u'this', u'British', u'industrial', u'conglomerate', u'.', u'.', u'START', u'A', u'form', u'of', u'asbestos', u'once', u'used', u'to', u'make', u'Kent', u'cigarette', u'filters', u'has', u'caused', u'a', u'high', u'percentage', u'of', u'cancer', u'deaths', u'among', u'a', u'group', u'of', u'workers', u'exposed', u'to', u'it', u'more', u'than', u'30', u'years', u'ago', u',', u'researchers', u'reported', u'.']
# [u'The', u'asbestos', u'fiber', u',', u'crocidolite', u',', u'is', u'unusually', u'resilient', u'once', u'it', u'enters', u'the', u'lungs', u',', u'with', u'even', u'brief', u'exposures', u'to', u'it', u'causing', u'symptoms', u'that', u'show', u'up', u'decades', u'later', u',', u'researchers', u'said', u'.']
# [u'Lorillard', u'Inc', u'.,', u'the', u'unit', u'of', u'New', u'York', u'-', u'based', u'Loews', u'Corp', u'.', u'that', u'makes', u'Kent', u'cigarettes', u',', u'stopped', u'using', u'crocidolite', u'in', u'its', u'Micronite', u'cigarette', u'filters', u'in', u'1956', u'.']
# [u'Although', u'preliminary', u'findings', u'were', u'reported', u'more', u'than', u'a', u'year', u'ago', u',', u'the', u'latest', u'results', u'appear', u'in', u'today', u"'", u's', u'New', u'England', u'Journal', u'of', u'Medicine', u',', u'a', u'forum', u'likely', u'to', u'bring', u'new', u'attention', u'to', u'the', u'problem', u'.']
# [u'A', u'Lorillard', u'spokewoman', u'said', u',', u'"', u'This', u'is', u'an', u'old', u'story', u'.']
# [u'We', u"'", u're', u'talking', u'about', u'years', u'ago', u'before', u'anyone', u'heard', u'of', u'asbestos', u'having', u'any', u'questionable', u'properties', u'.']
# [u'There', u'is', u'no', u'asbestos', u'in', u'our', u'products', u'now', u'."', u'Neither', u'Lorillard', u'nor', u'the', u'researchers', u'who', u'studied', u'the', u'workers', u'were', u'aware', u'of', u'any', u'research', u'on', u'smokers', u'of', u'the', u'Kent', u'cigarettes', u'.']
# [u'"', u'We', u'have', u'no', u'useful', u'information', u'on', u'whether', u'users', u'are', u'at', u'risk', u',"', u'said', u'James', u'A', u'.', u'Talcott', u'of', u'Boston', u"'", u's', u'Dana', u'-', u'Farber', u'Cancer', u'Institute', u'.']
# [u'Dr', u'.', u'Talcott', u'led', u'a', u'team', u'of', u'researchers', u'from', u'the', u'National', u'Cancer', u'Institute', u'and', u'the', u'medical', u'schools', u'of', u'Harvard', u'University', u'and', u'Boston', u'University', u'.']
# [u'The', u'Lorillard', u'spokeswoman', u'said', u'asbestos', u'was', u'used', u'in', u'"', u'very', u'modest', u'amounts', u'"', u'in', u'making', u'paper', u'for', u'the', u'filters', u'in', u'the', u'early', u'1950s', u'and', u'replaced', u'with', u'a', u'different', u'type', u'of', u'filter', u'in', u'1956', u'.']
# [u'From', u'1953', u'to', u'1955', u',', u'9', u'.', u'8', u'billion', u'Kent', u'cigarettes', u'with', u'the', u'filters', u'were', u'sold', u',', u'the', u'company', u'said', u'.']
# [u'Among', u'33', u'men', u'who', u'worked', u'closely', u'with', u'the', u'substance', u',', u'28', u'have', u'died', u'--', u'more', u'than', u'three', u'times', u'the', u'expected', u'number', u'.']
# [u'Four', u'of', u'the', u'five', u'surviving', u'workers', u'have', u'asbestos', u'-', u'related', u'diseases', u',', u'including', u'three', u'with', u'recently', u'diagnosed', u'cancer', u'.']
# [u'The', u'total', u'of', u'18', u'deaths', u'from', u'malignant', u'mesothelioma', u',', u'lung', u'cancer', u'and', u'asbestosis', u'was', u'far', u'higher', u'than', u'expected', u',', u'the', u'researchers', u'said', u'.']
# [u'"', u'The', u'morbidity', u'rate', u'is', u'a', u'striking', u'finding', u'among', u'those', u'of', u'us', u'who', u'study', u'asbestos', u'-', u'related', u'diseases', u',"', u'said', u'Dr', u'.', u'Talcott', u'.']
# [u'The', u'percentage', u'of', u'lung', u'cancer', u'deaths', u'among', u'the', u'workers', u'at', u'the', u'West', u'Groton', u',', u'Mass', u'.,', u'paper', u'factory', u'appears', u'to', u'be', u'the', u'highest', u'for', u'any', u'asbestos', u'workers', u'studied', u'in', u'Western', u'industrialized', u'countries', u',', u'he', u'said', u'.']
# [u'The', u'plant', u',', u'which', u'is', u'owned', u'by', u'Hollingsworth', u'&', u'Vose', u'Co', u'.,', u'was', u'under', u'contract', u'with', u'Lorillard', u'to', u'make', u'the', u'cigarette', u'filters', u'.']
# [u'The', u'finding', u'probably', u'will', u'support', u'those', u'who', u'argue', u'that', u'the', u'U', u'.', u'S', u'.', u'should', u'regulate', u'the', u'class', u'of', u'asbestos', u'including', u'crocidolite', u'more', u'stringently', u'than', u'the', u'common', u'kind', u'of', u'asbestos', u',', u'chrysotile', u',', u'found', u'in', u'most', u'schools', u'and', u'other', u'buildings', u',', u'Dr', u'.', u'Talcott', u'said', u'.']
# [u'The', u'U', u'.', u'S', u'.', u'is', u'one', u'of', u'the', u'few', u'industrialized', u'nations', u'that', u'doesn', u"'", u't', u'have', u'a', u'higher', u'standard', u'of', u'regulation', u'for', u'the', u'smooth', u',', u'needle', u'-', u'like', u'fibers', u'such', u'as', u'crocidolite', u'that', u'are', u'classified', u'as', u'amphobiles', u',', u'according', u'to', u'Brooke', u'T', u'.', u'Mossman', u',', u'a', u'professor', u'of', u'pathlogy', u'at', u'the', u'University', u'of', u'Vermont', u'College', u'of', u'Medicine', u'.']
# [u'More', u'common', u'chrysotile', u'fibers', u'are', u'curly', u'and', u'are', u'more', u'easily', u'rejected', u'by', u'the', u'body', u',', u'Dr', u'.', u'Mossman', u'explained', u'.']
# [u'In', u'July', u',', u'the', u'Environmental', u'Protection', u'Agency', u'imposed', u'a', u'gradual', u'ban', u'on', u'virtually', u'all', u'uses', u'of', u'asbestos', u'.']
# [u'By', u'1997', u',', u'almost', u'all', u'remaining', u'uses', u'of', u'cancer', u'-', u'causing', u'asbestos', u'will', u'be', u'outlawed', u'.']
# [u'About', u'160', u'workers', u'at', u'a', u'factory', u'that', u'made', u'paper', u'for', u'the', u'Kent', u'filters', u'were', u'exposed', u'to', u'asbestos', u'in', u'the', u'1950s', u'.']
# [u'Areas', u'of', u'the', u'factory', u'were', u'particularly', u'dusty', u'where', u'the', u'crocidolite', u'was', u'used', u'.']
# [u'Workers', u'dumped', u'large', u'burlap', u'sacks', u'of', u'the', u'imported', u'material', u'into', u'a', u'huge', u'bin', u',', u'poured', u'in', u'cotton', u'and', u'acetate', u'fibers', u'and', u'mechanically', u'mixed', u'the', u'dry', u'fibers', u'in', u'a', u'process', u'used', u'to', u'make', u'filters', u'.']
# [u'Workers', u'described', u'"', u'clouds', u'of', u'blue', u'dust', u'"', u'that', u'hung', u'over', u'parts', u'of', u'the', u'factory', u',', u'even', u'though', u'exhaust', u'fans', u'ventilated', u'the', u'area', u'.', u'"', u'There', u"'", u's', u'no', u'question', u'that', u'some', u'of', u'those', u'workers', u'and', u'managers', u'contracted', u'asbestos', u'-', u'related', u'diseases', u',"', u'said', u'Darrell', u'Phillips', u',', u'vice', u'president', u'of', u'human', u'resources', u'for', u'Hollingsworth', u'&', u'Vose', u'.', u'"', u'But', u'you', u'have', u'to', u'recognize', u'that', u'these', u'events', u'took', u'place', u'35', u'years', u'ago', u'.']
# [u'It', u'has', u'no', u'bearing', u'on', u'our', u'work', u'force', u'today', u'."', u'.', u'START', u'Yields', u'on', u'money', u'-', u'market', u'mutual', u'funds', u'continued', u'to', u'slide', u',', u'amid', u'signs', u'that', u'portfolio', u'managers', u'expect', u'further', u'declines', u'in', u'interest', u'rates', u'.']
# [u'The', u'average', u'seven', u'-', u'day', u'compound', u'yield', u'of', u'the', u'400', u'taxable', u'funds', u'tracked', u'by', u'IBC', u'/', u'Donoghue', u"'", u's', u'Money', u'Fund', u'Report', u'eased', u'a', u'fraction', u'of', u'a', u'percentage', u'point', u'to', u'8', u'.', u'45', u'%', u'from', u'8', u'.', u'47', u'%', u'for', u'the', u'week', u'ended', u'Tuesday', u'.']
# [u'Compound', u'yields', u'assume', u'reinvestment', u'of', u'dividends', u'and', u'that', u'the', u'current', u'yield', u'continues', u'for', u'a', u'year', u'.']
# [u'Average', u'maturity', u'of', u'the', u'funds', u"'", u'investments', u'lengthened', u'by', u'a', u'day', u'to', u'41', u'days', u',', u'the', u'longest', u'since', u'early', u'August', u',', u'according', u'to', u'Donoghue', u"'", u's', u'.', u'Longer', u'maturities', u'are', u'thought', u'to', u'indicate', u'declining', u'interest', u'rates', u'because', u'they', u'permit', u'portfolio', u'managers', u'to', u'retain', u'relatively', u'higher', u'rates', u'for', u'a', u'longer', u'period', u'.']
# [u'Shorter', u'maturities', u'are', u'considered', u'a', u'sign', u'of', u'rising', u'rates', u'because', u'portfolio', u'managers', u'can', u'capture', u'higher', u'rates', u'sooner', u'.']
# [u'The', u'average', u'maturity', u'for', u'funds', u'open', u'only', u'to', u'institutions', u',', u'considered', u'by', u'some', u'to', u'be', u'a', u'stronger', u'indicator', u'because', u'those', u'managers', u'watch', u'the']

# %%
# compare to NLKT default sentence tokenizer, which works on raw text instead of tokens
from nltk.tokenize import sent_tokenize

# %%
# this sentence segmenter starts with raw text, instead of tokens
rawtext = 'Pierre Vinken, 61 years old, will join the board as a nonexecutive director Nov. 29.  Mr. Vinken is chairman of Elsevier N.V., the Dutch publishing group.'
sents = nltk.sent_tokenize(rawtext)
sents
# Out:
# ['Pierre Vinken, 61 years old, will join the board as a nonexecutive director Nov. 29.',
#  'Mr. Vinken is chairman of Elsevier N.V., the Dutch publishing group.']

# %%
## classify documents based on keywords
from nltk.corpus import movie_reviews
import random

# %%
# movie reviews are labeled either positive or negative (by human annotators)
movie_reviews.categories()
# Out:
# [u'neg', u'pos']

# %%
# for each document in movie_reviews, get its words and category (positive/negative)
documents = [(list(movie_reviews.words(fileid)), category)
              for category in movie_reviews.categories()
              for fileid in movie_reviews.fileids(category)]
len(documents)
# Out:
# 2000

# %%
random.shuffle(documents)
# look at the first document - consists of a list of all the words in the review
# followed by the category
print(documents[0])
# Out:
# ([u'sometimes', u'a', u'stellar', u'cast', u'can', u'compensate', u'for', u'a', u'lot', u'of', u'things', u',', u'and', u'"', u'pushing', u'tin', u'"', u'certainly', u'features', u'some', u'name', u'stars', u'who', u'are', u'going', u'places', u':', u'billy', u'bob', u'thornton', u',', u'cate', u'blanchett', u',', u'angelina', u'jolie', u',', u'and', u'oh', u'yes', u'john', u'cusack', u'who', u'might', u'not', u'realize', u'it', u'at', u'first', u',', u'but', u'he', u"'", u's', u'actually', u'the', u'*', u'veteran', u'*', u'among', u'this', u'quartet', u'of', u'fine', u'-', u'looking', u'people', u'.', u'sometimes', u'a', u'terrific', u'cast', u'like', u'this', u'can', u'compensate', u'for', u'a', u'lackluster', u'screen', u'treatment', u'of', u'an', u'idea', u'that', u'has', u'"', u'hip', u'comedy', u'"', u'written', u'all', u'over', u'it', u',', u'compensate', u'for', u'workmanlike', u'but', u'uninspired', u'direction', u',', u'compensate', u'for', u'an', u'obnoxious', u'score', u'that', u'would', u'have', u'anyone', u'but', u'the', u'tone', u'deaf', u'screaming', u'for', u'the', u'exits', u',', u'compensate', u'for', u'clich', u'?', u'd', u'characterizations', u',', u'compensate', u'for', u'embarrassing', u'"', u'you', u'have', u'to', u'be', u'joking', u'"', u'situations', u'.', u'etc', u'.', u'in', u'"', u'pushing', u'tin', u',', u'"', u'thornton', u',', u'blanchett', u',', u'jolie', u',', u'and', u'cusack', u'don', u"'", u't', u'have', u'an', u'earthly', u'.', u'from', u'the', u'opening', u'sequence', u'the', u'film', u'is', u'in', u'big', u'trouble', u':', u'squiggly', u',', u'"', u'quirky', u'"', u'credits', u',', u'fake', u'-', u'looking', u'passenger', u'planes', u'circling', u'new', u'york', u',', u'and', u'anne', u'dudley', u"'", u's', u'in', u'-', u'your', u'-', u'ear', u'music', u'making', u'us', u'wonder', u'how', u'she', u'ever', u'got', u'that', u'best', u'original', u'score', u'nomination', u'for', u'"', u'the', u'full', u'monty', u',', u'"', u'let', u'alone', u'won', u'it', u'.', u'but', u'i', u',', u'for', u'one', u',', u'wasn', u"'", u't', u'ready', u'to', u'walk', u'just', u'yet', u'.', u'so', u'quickly', u'we', u'descend', u'into', u'a', u'tightly', u'-', u'edited', u'air', u'traffic', u'controllers', u'montage', u'which', u'screams', u'to', u'us', u'in', u'large', u'capital', u'letters', u'these', u'people', u'have', u'a', u'difficult', u'job', u',', u'yes', u',', u'what', u'with', u'their', u'frantic', u',', u'mile', u'-', u'a', u'-', u'minute', u'instructional', u'personas', u',', u'juggling', u'planes', u'and', u'passenger', u"'", u's', u'lives', u'like', u'some', u'huge', u',', u'real', u',', u'mid', u'-', u'air', u'video', u'game', u'.', u'hip', u',', u'cool', u',', u'demonic', u'auctioneer', u'nick', u'"', u'the', u'zone', u'"', u'falzone', u'(', u'cusack', u')', u'is', u'the', u'best', u'in', u'the', u'biz', u'.', u'of', u'course', u'.', u'until', u'some', u'hipper', u',', u'cooler', u',', u'leather', u'-', u'clad', u'flyboy', u'assist', u'in', u'the', u'guise', u'of', u'russell', u'bell', u'(', u'thornton', u')', u'shows', u'up', u'to', u'challenge', u'falzone', u"'", u's', u'finite', u'air', u'space', u'.', u'boys', u'will', u'be', u'boys', u'and', u'some', u'heavy', u'duty', u'testosterone', u'starts', u'exuding', u',', u'then', u'the', u'macho', u'one', u'-', u'upmanship', u'begins', u'.', u'it', u'doesn', u"'", u't', u'stop', u'with', u'seeing', u'who', u'can', u'juggle', u'three', u'747s', u'within', u'a', u'cat', u"'", u's', u'whisker', u'of', u'each', u'other', u'.', u'oh', u'no', u'.', u'there', u'are', u'some', u'broken', u'hoop', u'dreams', u',', u'some', u'wanna', u'-', u'see', u'-', u'how', u'-', u'fast', u'-', u'i', u'-', u'can', u'-', u'drives', u',', u'and', u'then', u'the', u'ultimate', u'showdown', u':', u'was', u'that', u'my', u'wife', u'i', u'saw', u'you', u'with', u'last', u'night', u'?', u'director', u'mike', u'newell', u'(', u'"', u'four', u'weddings', u'and', u'a', u'funera ...

# %%
## use words from all documents to define the word vector for features
# get all words from all movie_reviews and put into a frequency distribution
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
len(all_words)
# Out:
# 39768

# %%
# get the 2000 most frequently appearing keywords in the corpus
word_items = all_words.most_common(5005)
word_features = [word for (word, freq) in word_items]   # just the words

# look at the first 100 words
print(word_features[:100])
# Out:
# [u',', u'the', u'.', u'a', u'and', u'of', u'to', u"'", u'is', u'in', u's', u'"', u'it', u'that', u'-', u')', u'(', u'as', u'with', u'for', u'his', u'this', u'film', u'i', u'he', u'but', u'on', u'are', u't', u'by', u'be', u'one', u'movie', u'an', u'who', u'not', u'you', u'from', u'at', u'was', u'have', u'they', u'has', u'her', u'all', u'?', u'there', u'like', u'so', u'out', u'about', u'up', u'more', u'what', u'when', u'which', u'or', u'she', u'their', u':', u'some', u'just', u'can', u'if', u'we', u'him', u'into', u'even', u'only', u'than', u'no', u'time', u'good', u'most', u'its', u'will', u'story', u'would', u'been', u'much', u'character', u'also', u'get', u'other', u'do', u'two', u'well', u'them', u'very', u'characters', u';', u'first', u'--', u'after', u'see', u'!', u'way', u'because', u'make', u'life']

# %%
# define features (keywords) of a document
# each feature is 'contains(keyword)' and is true or false depending
# on whether that keyword is in the document
def document_features(document, word_features):
	document_words = set(document)
	features = {}
	for word in word_features:
		features['contains(%s)' % word] = (word in document_words)
	return features

# %%
# get features sets for a document, including keyword features and category feature
featuresets = [(document_features(d, word_features), c) for (d,c) in documents]

# the feature sets are 2000 words long - so this is optional
featuresets[0]
# Out:
# ({u'contains(waste)': False,
#   u'contains(menacing)': False,
#   u'contains(bag)': False,
#   u'contains(happily)': False,
#   u'contains(lot)': True,
#   u'contains(twisted)': False,
#   u'contains(slater)': False,
#   u'contains(*)': True,
#   u'contains(commercials)': False,
#   u'contains(debate)': False,
#   u'contains(black)': False,
#   u'contains(sand)': False,
#   u'contains(rated)': False,
#   u'contains(conventions)': False,
#   u'contains(copy)': False,
#   u'contains(mcconaughey)': False,
#   u'contains(potential)': False,
#   u'contains(response)': False,
#   u'contains(frequency)': False,
#   u'contains(m)': False,
#   u'contains(reaches)': False,
#   u'contains(verhoeven)': False,
#   u'contains(understand)': False,
#   u'contains(cost)': False,
#   u'contains(disguise)': False,
#   u'contains(everywhere)': False,
#   u'contains(drug)': False,
#   u'contains(1991)': False,
#   u'contains(enters)': False,
#   u'contains(campaign)': False,
#   u'contains(case)': False,
#   u'contains(reed)': False,
#   u'contains(floating)': False,
#   u'contains(respected)': False,
#   u'contains(faced)': False,
#   u'contains(created)': False,
#   u'contains(kiss)': False,
#   u'contains(needed)': False,
#   u'contains(explains)': False,
#   u'contains(c)': False,
#   u'contains(rick)': False,
#   u'contains(teens)': False,
#   u'contains(about)': False,
#   u'contains(technically)': False,
#   u'contains(havoc)': False,
#   u'contains(centers)': False,
#   u'contains(boiler)': False,
#   u'contains(fable)': False,
#   u'contains(toy)': False,
#   u'contains(projects)': False,
#   u'contains(catches)': False,
#   u'contains(airplane)': False,
#   u'contains(longer)': False,
#   u'contains(emperor)': False,
#   u'contains(fix)': False,
#   u'contains(ready)': True,
#   u'contains(theory)': False,
#   u'contains(certainly)': True,
#   u'contains(lawrence)': False,
#   u'contains(affection)': False,
#   u'contains(chambers)': False,
#   u'contains(luis)': False,
#   u'contains(paxton)': False,
#   u'contains(sidekick)': False,
#   u'contains(ghosts)': False,
#   u'contains(favor)': False,
#   u'contains(choreographed)': False,
#   u'contains(gilliam)': False,
#   u'contains(lame)': False,
#   u'contains(subtlety)': True,
#   u'contains(sadly)': False,
#   u'contains(anderson)': False,
#   u'contains(lemmon)': False,
#   u'contains(dare)': False,
#   u'contains(southern)': False,
#   u'contains(angel)': False,
#   u'contains(rent)': False,
#   u'contains(trend)': False,
#   u'contains(teeth)': False,
#   u'contains(arrival)': False,
#   u'contains(sweetback)': False,
#   u'contains(mulan)': False,
#   u'contains(primarily)': False,
#   u'contains(represents)': False,
#   u'contains(catherine)': False,
#   u'contains(australia)': False,
#   u'contains(fans)': False,
#   u'contains(wright)': False,
#   u'contains(1995)': False,
#   u'contains(narration)': False,
#   u'contains(christopher)': False,
#   u'contains(believing)': False,
#   u'contains(pierce)': False,
#   u'contains(davis)': False,
#   u'contains(spoil)': False,
#   u'contains(them)': False,
#   u'contains(seen)': False,
#   u'contains(fan)': False,
#   u'contains(robin)': False,
#   u'contains(controversial)': False,
#   u'contains(continually)': False,
#   u'contains(inane)': False,
#   u'contains(moments)': False,
#   u'contains(1900)': False,
#   u'contains(jim)': False,
#   u'contains(cinematic)': False,
#   u'contains(know)': False,
#   u'contains(fiennes)': False,
#   u'contains(deal)': False,
#   u'contains(trick)': False,
#   u'contains(law)': False,
#   u'contains(bone)': False,
#   u'contains(dimension)': False,
#   u'contains(started)': False,
#   u'contains(is)': True,
#   u'contains(violence)': False,
#   u'contains(brutal)': False,
#   u'contains(tension)': False,
#   u'contains(galaxy)': False,
#   u'contains(saying)': False,
#   u'contains(eats)': False,
#   u'contains(justice)': False,
#   u'contains(disappears)': False,
#   u'contains(focus)': False,
#   u'contains(suspects)': False,
#   u'contains(crude)': False,
#   u'contains($)': False,
#   u'contains(images)': False,
#   u'contains(cooking)': False,
#   u'contains(driver)': False,
#   u'contains(kicking)': False,
#   u'contains(burning)': False,
#   u'contains(feature)': False,
#   u'contains(crawford)': False,
#   u'contains(knew)': False,
#   u'contains(rape)': False,
#   u'contains(charlotte)': False,
#   u'contains(off)': False,
#   u'contains(fiction)': False,
#   u'contains(designer)': False,
#   u'contains(interviews)': False,
#   u'contains(drawn)': False,
#   u'contains(seattle)': False,
#   u'contains(helen)': False,
#   u'contains(blend)': False,
#   u'contains(road)': False,
#   u'contains(fi)': False,
#   u'contains(surviving)': False,
#   u'contains(johnson)': False,
#   u'contains(hears)': False,
#   u'contains(hook)': False,
#   u'contains(films)': False,
#   u'contains(rudy)': False,
#   u'contains(ribisi)': False,
#   u'contains(troopers)': False,
#   u'contains(comedic)': False,
#   u'contains(mediocre)': False,
#   u'contains(players)': False,
#   u'contains(data)': False,
#   u'contains(attention)': False,
#   u'contains(morgan)': False,
#   u'contains(wannabe)': False,
#   u'contains(aliens)': False,
#   u'contains(phony)': False,
#   u'contains(keanu)': False,
#   u'contains(excuse)': False,
#   u'contains(appreciate)': False,
#   u'contains(younger)': False,
#   u'contains(son)': False,
#   u'contains(rain)': False,
#   u'contains(16)': False,
#   u'contains(hype)': False,
#   u'contains(sleep)': False,
#   u'contains(unhappy)': False,
#   u'contains(check)': False,
#   u'contains(hold)': False,
#   u'contains(ward)': False,
#   u'contains(decidedly)': False,
#   u'contains(defeat)': False,
#   u'contains(crazy)': False,
#   u'contains(respectively)': False,
#   u'contains(visits)': False,
#   u'contains(scares)': False,
#   u'contains(dreadful)': False,
#   u'contains(seemingly)': False,
#   u'contains(deniro)': False,
#   u'contains(paris)': False,
#   u'contains(blast)': False,
#   u'contains(rubin)': False,
#   u'contains(sinise)': False,
#   u'contains(depth)': False,
#   u'contains(respect)': False,
#   u'contains(hip)': True,
#   u'contains(finger)': False,
#   u'contains(voiced)': False,
#   u'contains(forgot)': False,
#   u'contains(drop)': False,
#   u'contains(lower)': False,
#   u'contains(boring)': False,
#   u'contains(robinson)': False,
#   u'contains(fear)': False,
#   u'contains(watched)': False,
#   u'contains(corrupt)': False,
#   u'contains(knows)': False,
#   u'contains(directed)': False,
#   u'contains(distracting)': False,
#   u'contains(crisp)': False,
#   u'contains(acceptable)': False,
#   u'contains(shots)': False,
#   u'contains(sign)': False,
#   u'contains(heche)': False,
#   u'contains(torn)': False,
#   u'contains(charge)': False,
#   u'contains(garofalo)': False,
#   u'contains(miscast)': False,
#   u'contains(hearing)': False,
#   u'contains(themes)': False,
#   u'contains(scene)': False,
#   u'contains(cares)': False,
#   u'contains(oscar)': True,
#   u'contains(shock)': False,
#   u'contains(reviews)': False,
#   u'contains(craig)': False,
#   u'contains(niro)': False,
#   u'contains(monkey)': False,
#   u'contains(wahlberg)': False,
#   u'contains(criticism)': False,
#   u'contains(cab)': False,
#   u'contains(distant)': False,
#   u'contains(viewers)': False,
#   u'contains(aid)': False,
#   u'contains(screenplay)': False,
#   u'contains(stranger)': False,
#   u'contains(talk)': False,
#   u'contains(standing)': False,
#   u'contains(sudden)': False,
#   u'contains(iron)': False,
#   u'contains(number)': False,
#   u'contains(followed)': False,
#   u'contains(extras)': False,
#   u'contains(displays)': False,
#   u'contains(events)': False,
#   u'contains(deserves)': False,
#   u'contains(gene)': False,
#   u'contains(insists)': False,
#   u'contains(detroit)': False,
#   u'contains(receiving)': False,
#   u'contains(cannot)': False,
#   u'contains(gangster)': False,
#   u'contains(irony)': False,
#   u'contains(awe)': False,
#   u'contains(shoot)': False,
#   u'contains(space)': True,
#   u'contains(worn)': False,
#   u'contains(lasting)': False,
#   u'contains(scripts)': False,
#   u'contains(vegas)': False,
#   u'contains(which)': True,
#   u'contains(lee)': False,
#   u'contains(director)': True,
#   u'contains(disappear)': False,
#   u'contains(thousand)': False,
#   u'contains(etc)': True,
#   u'contains(heavy)': True,
#   u'contains(heartfelt)': False,
#   u'contains(trip)': False,
#   u'contains(similarly)': False,
#   u'contains(daniel)': False,
#   u'contains(un)': False,
#   u'contains(begin)': True,
#   u'contains(covered)': False,
#   u'contains(deliciously)': False,
#   u'contains(themselves)': False,
#   u'contains(co)': False,
#   u'contains(initial)': False,
#   u'contains(arnold)': False,
#   u'contains(fbi)': False,
#   u'contains(than)': True,
#   u'contains(raising)': False,
#   u'contains(crowd)': False,
#   u'contains(harder)': False,
#   u'contains(shows)': True,
#   u'contains(instantly)': False,
#   u'contains(award)': False,
#   u'contains(eve)': False,
#   u'contains(ridiculously)': False,
#   u'contains(despite)': False,
#   u'contains(fluff)': False,
#   u'contains(dose)': False,
#   u'contains(gavin)': False,
#   u'contains(possesses)': False,
#   u'contains(lousy)': False,
#   u'contains(worlds)': False,
#   u'contains(go)': True,
#   u'contains(hills)': False,
#   u'contains(anna)': False,
#   u'contains(speed)': False,
#   u'contains(mouth)': False,
#   u'contains(serial)': False,
#   u'contains(courtesy)': False,
#   u'contains(characterization)': False,
#   u'contains(roles)': False,
#   u'contains(fantasy)': False,
#   u'contains(depressing)': False,
#   u'contains(pleasing)': False,
#   u'contains(amount)': False,
#   u'contains(latter)': False,
#   u'contains(evidence)': False,
#   u'contains(promised)': False,
#   u'contains(henry)': False,
#   u'contains(unnecessary)': False,
#   u'contains(sharon)': False,
#   u'contains(weary)': False,
#   u'contains(days)': False,
#   u'contains(cultural)': False,
#   u'contains(museum)': False,
#   u'contains(strange)': False,
#   u'contains(just)': True,
#   u'contains(on)': False,
#   u'contains(security)': False,
#   u'contains(zone)': True,
#   u'contains(matthau)': False,
#   u'contains(hospital)': False,
#   u'contains(gus)': False,
#   u'contains(limits)': False,
#   u'contains(reminds)': False,
#   u'contains(had)': False,
#   u'contains(nature)': False,
#   u'contains(brains)': False,
#   u'contains(proportions)': False,
#   u'contains(sinister)': False,
#   u'contains(overcome)': False,
#   u'contains(restraint)': False,
#   u'contains(sees)': False,
#   u'contains(6)': False,
#   u'contains(fictional)': False,
#   u'contains(goldberg)': False,
#   u'contains(entertainment)': False,
#   u'contains(disc)': False,
#   u'contains(typically)': False,
#   u'contains(philosophical)': False,
#   u'contains(introduces)': False,
#   u'contains(fifth)': False,
#   u'contains(cat)': True,
#   u'contains(bad)': True,
#   u'contains(advocate)': False,
#   u'contains(stalked)': False,
#   u'contains(park)': False,
#   u'contains(bond)': False,
#   u'contains(bug)': False,
#   u'contains(rocks)': False,
#   u'contains(lean)': False,
#   u'contains(genuinely)': False,
#   u'contains(fake)': True,
#   u'contains(hear)': False,
#   u'contains(audience)': False,
#   u'contains(paradise)': False,
#   u'contains(lou)': False,
#   u'contains(jedi)': False,
#   u'contains(lends)': False,
#   u'contains(literally)': False,
#   u'contains(banderas)': False,
#   u'contains(strong)': False,
#   u'contains(maintain)': False,
#   u'contains(jackson)': False,
#   u'contains(normally)': False,
#   u'contains(postman)': False,
#   u'contains(considered)': False,
#   u'contains(l)': False,
#   u'contains(segment)': False,
#   u'contains(interest)': False,
#   u'contains(drives)': True,
#   u'contains(outrageous)': False,
#   u'contains(montage)': True,
#   u'contains(perform)': False,
#   u'contains(ross)': False,
#   u'contains(b)': False,
#   u'contains(staff)': False,
#   u'contains(gross)': False,
#   u'contains(griffith)': False,
#   u'contains(provoking)': False,
#   u'contains(damon)': False,
#   u'contains(dropping)': False,
#   u'contains(lebowski)': False,
#   u'contains(soap)': False,
#   u'contains(answer)': False,
#   u'contains(dozens)': False,
#   u'contains(dubious)': False,
#   u'contains(serious)': False,
#   u'contains(hopes)': False,
#   u'contains(dancing)': False,
#   u'contains(opens)': False,
#   u'contains(top)': False,
#   u'contains(degree)': False,
#   u'contains(concerning)': False,
#   u'contains(ask)': False,
#   u'contains(seemed)': False,
#   u'contains(portrays)': False,
#   u'contains(called)': False,
#   u'contains(smaller)': False,
#   u'contains(history)': False,
#   u'contains(juliet)': False,
#   u'contains(theaters)': False,
#   u'contains(wear)': False,
#   u'contains(waves)': False,
#   u'contains(horny)': False,
#   u'contains(inducing)': False,
#   u'contains(hysterical)': False,
#   u'contains(cars)': False,
#   u'contains(discovered)': False,
#   u'contains(sits)': False,
#   u'contains(miami)': False,
#   u'contains(environment)': False,
#   u'contains(logic)': False,
#   u'contains(jumps)': False,
#   u'contains(performance)': True,
#   u'contains(described)': False,
#   u'contains(holds)': False,
#   u'contains(against)': False,
#   u'contains(winning)': False,
#   u'contains(vehicle)': False,
#   u'contains(vaguely)': False,
#   u'contains(nelson)': False,
#   u'contains(physical)': False,
#   u'contains(jr)': False,
#   u'contains(5)': False,
#   u'contains(melodramatic)': False,
#   u'contains(kids)': False,
#   u'contains(mentioned)': False,
#   u'contains(simply)': False,
#   u'contains(although)': False,
#   u'contains(unfortunately)': False,
#   u'contains(forth)': False,
#   u'contains(greed)': False,
#   u'contains(drive)': False,
#   u'contains(noticeable)': False,
#   u'contains(baby)': False,
#   u'contains(apartment)': False,
#   u'contains(unfortunate)': False,
#   u'contains(trail)': False,
#   u'contains(unintentionally)': False,
#   u'contains(stahl)': False,
#   u'contains(rule)': False,
#   u'contains(satirical)': False,
#   u'contains(hits)': False,
#   u'contains(susan)': False,
#   u'contains(bont)': False,
#   u'contains(middle)': False,
#   u'contains(was)': True,
#   u'contains(glory)': False,
#   u'contains(wings)': False,
#   u'contains(jesus)': False,
#   u'contains(guess)': False,
#   u'contains(heroin)': False,
#   u'contains(dress)': False,
#   u'contains(silent)': False,
#   u'contains(delivering)': False,
#   u'contains(buried)': False,
#   u'contains(hence)': False,
#   u'contains(payback)': False,
#   u'contains(wonder)': True,
#   u'contains(plots)': False,
#   u'contains(richardson)': False,
#   u'contains(flick)': False,
#   u'contains(male)': False,
#   u'contains(acclaimed)': False,
#   u'contains(fun)': False,
#   u'contains(factor)': False,
#   u'contains(armageddon)': False,
#   u'contains(generally)': False,
#   u'contains(carefully)': False,
#   u'contains(denzel)': False,
#   u'contains(shaw)': False,
#   u'contains(room)': False,
#   u'contains(used)': False,
#   u'contains(er)': False,
#   u'contains(stern)': False,
#   u'contains(exploration)': False,
#   u'contains(score)': True,
#   u'contains(eyes)': False,
#   u'contains(connected)': False,
#   u'contains(didn)': False,
#   u'contains(born)': False,
#   u'contains(rebecca)': False,
#   u'contains(indian)': False,
#   u'contains(extended)': False,
#   u'contains(court)': False,
#   u'contains(wins)': False,
#   u'contains(jail)': False,
#   u'contains(reasonable)': False,
#   u'contains(follow)': False,
#   u'contains(state)': False,
#   u'contains(apostle)': False,
#   u'contains(end)': False,
#   u'contains(actions)': False,
#   u'contains(heard)': False,
#   u'contains(egoyan)': False,
#   u'contains(funny)': True,
#   u'contains(twilight)': False,
#   u'contains(melvin)': False,
#   u'contains(insurance)': False,
#   u'contains(opinion)': False,
#   u'contains(replaced)': False,
#   u'contains(flesh)': False,
#   u'contains(loves)': False,
#   u'contains(surreal)': False,
#   u'contains(bite)': False,
#   u'contains(possessed)': False,
#   u'contains(lets)': False,
#   u'contains(brenner)': False,
#   u'contains(backdrop)': False,
#   u'contains(martin)': False,
#   u'contains(afterwards)': False,
#   u'contains(predictable)': False,
#   u'contains(hey)': False,
#   u'contains(sincere)': False,
#   u'contains(depression)': False,
#   u'contains(nuclear)': False,
#   u'contains(absolutely)': False,
#   u'contains(hole)': False,
#   u'contains(luke)': False,
#   u'contains(pants)': False,
#   u'contains(action)': False,
#   u'contains(companion)': False,
#   u'contains(gattaca)': False,
#   u'contains(another)': False,
#   u'contains(mercury)': False,
#   u'contains(martian)': False,
#   u'contains(spiritual)': False,
#   u'contains(carrey)': False,
#   u'contains(below)': False,
#   u'contains(neo)': False,
#   u'contains(passion)': False,
#   u'contains(hadn)': False,
#   u'contains(professional)': False,
#   u'contains(captured)': False,
#   u'contains(pivotal)': False,
#   u'contains(turmoil)': False,
#   u'contains(theme)': False,
#   u'contains(disease)': False,
#   u'contains(stop)': True,
#   u'contains(indiana)': False,
#   u'contains(threatening)': False,
#   u'contains(drew)': False,
#   u'contains(supposed)': False,
#   u'contains(cartoonish)': False,
#   u'contains(what)': True,
#   u'contains(scared)': False,
#   u'contains(travis)': False,
#   u'contains(psychologist)': False,
#   u'contains(include)': False,
#   u'contains(hair)': False,
#   u'contains(meg)': False,
#   u'contains(chicago)': False,
#   u'contains(highlights)': False,
#   u'contains(rather)': False,
#   u'contains(prominent)': False,
#   u'contains(carry)': False,
#   u'contains(embarrassed)': False,
#   u'contains(hidden)': False,
#   u'contains(michelle)': False,
#   u'contains(ways)': False,
#   u'contains(element)': False,
#   u'contains(intention)': False,
#   u'contains(fatal)': False,
#   u'contains(alive)': False,
#   u'contains(anyway)': False,
#   u'contains(pulled)': False,
#   u'contains(suave)': False,
#   u'contains(zeta)': False,
#   u'contains(hannah)': False,
#   u'contains(laugh)': False,
#   u'contains(program)': False,
#   u'contains(immensely)': False,
#   u'contains(carter)': False,
#   u'contains(cult)': False,
#   u'contains(realm)': False,
#   u'contains(tall)': False,
#   u'contains(spare)': False,
#   u'contains(slightest)': False,
#   u'contains(turns)': False,
#   u'contains(master)': False,
#   u'contains(ruthless)': False,
#   u'contains(talented)': False,
#   u'contains(abyss)': False,
#   u'contains(includes)': False,
#   u'contains(skip)': False,
#   u'contains(innocent)': False,
#   u'contains(path)': False,
#   u'contains(mountains)': False,
#   u'contains(boot)': False,
#   u'contains(terry)': False,
#   u'contains(proving)': False,
#   u'contains(has)': True,
#   u'contains(sam)': False,
#   u'contains(episodes)': False,
#   u'contains(engaged)': False,
#   u'contains(ocean)': False,
#   u'contains(mask)': False,
#   u'contains(rough)': False,
#   u'contains(betty)': False,
#   u'contains(climactic)': False,
#   u'contains(candidate)': False,
#   u'contains(horribly)': False,
#   u'contains(laid)': False,
#   u'contains(sure)': False,
#   u'contains(hoffman)': False,
#   u'contains(load)': False,
#   u'contains(whatever)': False,
#   u'contains(owns)': False,
#   u'contains(times)': False,
#   u'contains(jeffrey)': False,
#   u'contains(incredible)': False,
#   u'contains(slight)': False,
#   u'contains(inside)': False,
#   u'contains(impressed)': False,
#   u'contains(ingredients)': False,
#   u'contains(viewer)': False,
#   u'contains(routine)': False,
#   u'contains(plot)': False,
#   u'contains(trees)': False,
#   u'contains(enterprise)': False,
#   u'contains(mate)': False,
#   u'contains(hearts)': False,
#   u'contains(destroying)': False,
#   u'contains(mouse)': False,
#   u'contains(seagal)': False,
#   u'contains(crowe)': False,
#   u'contains(tunnel)': False,
#   u'contains(mile)': True,
#   u'contains(solve)': False,
#   u'contains(birthday)': False,
#   u'contains(aware)': False,
#   u'contains(speaking)': False,
#   u'contains(easily)': False,
#   u'contains(very)': False,
#   u'contains(department)': False,
#   u'contains(uninteresting)': False,
#   u'contains(already)': False,
#   u'contains(setting)': False,
#   u'contains(trapped)': False,
#   u'contains(really)': False,
#   u'contains(perry)': False,
#   u'contains(arthur)': False,
#   u'contains(screenwriter)': False,
#   u'contains(admittedly)': False,
#   u'contains(occasionally)': False,
#   u'contains(cliched)': False,
#   u'contains(tried)': False,
#   u'contains(whenever)': False,
#   u'contains(workers)': False,
#   u'contains(ass)': False,
#   u'contains(proves)': False,
#   u'contains(al)': False,
#   u'contains(hours)': False,
#   u'contains(wanders)': False,
#   u'contains(fargo)': False,
#   u'contains(closing)': False,
#   u'contains(mood)': False,
#   u'contains(weeks)': False,
#   u'contains(strikes)': False,
#   u'contains(real)': True,
#   u'contains(meanwhile)': False,
#   u'contains(create)': False,
#   u'contains(mob)': False,
#   u'contains(religion)': False,
#   u'contains(slowly)': False,
#   u'contains(dillon)': False,
#   u'contains(pun)': False,
#   u'contains(resolution)': False,
#   u'contains(offers)': False,
#   u'contains(age)': False,
#   u'contains(lighting)': False,
#   u'contains(psychic)': False,
#   u'contains(want)': False,
#   u'contains(huge)': True,
#   u'contains(albert)': False,
#   u'contains(same)': False,
#   u'contains(close)': False,
#   u'contains(subplot)': False,
#   u'contains(property)': False,
#   u'contains(james)': False,
#   u'contains(nation)': False,
#   u'contains(arms)': False,
#   u'contains(troubles)': False,
#   u'contains(ellie)': False,
#   u'contains(throat)': False,
#   u'contains(achievement)': False,
#   u'contains(faces)': False,
#   u'contains(colony)': False,
#   u'contains(discovers)': False,
#   u'contains(ironic)': False,
#   u'contains(tour)': False,
#   u'contains(selfish)': False,
#   u'contains(late)': True,
#   u'contains(liked)': False,
#   u'contains(astronauts)': False,
#   u'contains(reeves)': False,
#   u'contains(distraction)': False,
#   u'contains(pathetic)': False,
#   u'contains(imaginative)': False,
#   u'contains(andy)': False,
#   u'contains(wind)': False,
#   u'contains(hated)': False,
#   u'contains(heather)': False,
#   u'contains(trek)': False,
#   u'contains(nasa)': False,
#   u'contains(spot)': False,
#   u'contains(federal)': False,
#   u'contains(nearby)': False,
#   u'contains(inept)': False,
#   u'contains(ball)': False,
#   u'contains(marshall)': False,
#   u'contains(suffering)': False,
#   u'contains(ugly)': False,
#   u'contains(adam)': False,
#   u'contains(stock)': False,
#   u'contains(theatre)': False,
#   u'contains(pale)': False,
#   u'contains(competition)': False,
#   u'contains(absolute)': False,
#   u'contains(sword)': False,
#   u'contains(bought)': False,
#   u'contains(doomed)': False,
#   u'contains(often)': False,
#   u'contains(com)': False,
#   u'contains(shines)': False,
#   u'contains(funniest)': False,
#   u'contains(wanting)': False,
#   u'contains(dance)': False,
#   u'contains(oldman)': False,
#   u'contains(lead)': False,
#   u'contains(place)': False,
#   u'contains(douglas)': False,
#   u'contains(ralph)': False,
#   u'contains(s)': True,
#   u'contains(troops)': False,
#   u'contains(multiple)': False,
#   u'contains(outside)': False,
#   u'contains(problems)': False,
#   u'contains(made)': True,
#   u'contains(starring)': False,
#   u'contains(attacks)': False,
#   u'contains(consequences)': False,
#   u'contains(shown)': False,
#   u'contains(forgotten)': False,
#   u'contains(worst)': False,
#   u'contains(instance)': False,
#   u'contains(a)': True,
#   u'contains(pregnant)': False,
#   u'contains(dawn)': False,
#   u'contains(string)': False,
#   u'contains(killing)': False,
#   u'contains(shut)': False,
#   u'contains(superior)': False,
#   u'contains(magical)': False,
#   u'contains(de)': False,
#   u'contains(ride)': False,
#   u'contains(mix)': False,
#   u'contains(closer)': False,
#   u'contains(argument)': False,
#   u'contains(circumstances)': False,
#   u'contains(tarzan)': False,
#   u'contains(process)': False,
#   u'contains(opening)': True,
#   u'contains(p)': False,
#   u'contains(jawbreaker)': False,
#   u'contains(caliber)': False,
#   u'contains(creator)': False,
#   u'contains(depiction)': False,
#   u'contains(threatens)': False,
#   u'contains(stick)': False,
#   u'contains(spaceship)': False,
#   u'contains(needless)': False,
#   u'contains(search)': False,
#   u'contains(50)': False,
#   u'contains(profession)': False,
#   u'contains(america)': False,
#   u'contains(worried)': False,
#   u'contains(brother)': False,
#   u'contains(cure)': False,
#   u'contains(primary)': False,
#   u'contains(causes)': False,
#   u'contains(foul)': False,
#   u'contains(goes)': False,
#   u'contains(hudson)': False,
#   u'contains(becoming)': False,
#   u'contains(4)': False,
#   u'contains(exceptional)': False,
#   u'contains(business)': False,
#   u'contains(mulder)': False,
#   u'contains(meaningful)': False,
#   u'contains(carol)': False,
#   u'contains(idiotic)': False,
#   u'contains(courtney)': False,
#   u'contains(tarantino)': False,
#   u'contains(potentially)': False,
#   u'contains(freeze)': False,
#   u'contains(insulting)': False,
#   u'contains(flashy)': False,
#   u'contains(derek)': False,
#   u'contains(robot)': False,
#   u'contains(mail)': False,
#   u'contains(wit)': False,
#   u'contains(material)': False,
#   u'contains(came)': False,
#   u'contains(war)': False,
#   u'contains(files)': False,
#   u'contains(hands)': False,
#   u'contains(style)': False,
#   u'contains(results)': False,
#   u'contains(factory)': False,
#   u'contains(himself)': False,
#   u'contains(redemption)': False,
#   u'contains(dumber)': False,
#   u'contains(winner)': False,
#   u'contains(issue)': False,
#   u'contains(lopez)': False,
#   u'contains(breakdown)': False,
#   u'contains(vampire)': False,
#   u'contains(recognition)': False,
#   u'contains(may)': False,
#   u'contains(porter)': False,
#   u'contains(leave)': False,
#   u'contains(joel)': False,
#   u'contains(cook)': False,
#   u'contains(lengthy)': False,
#   u'contains(stories)': False,
#   u'contains(couldn)': False,
#   u'contains(unlike)': False,
#   u'contains(lies)': False,
#   u'contains(promising)': False,
#   u'contains(thomas)': False,
#   u'contains(fingers)': False,
#   u'contains(trilogy)': False,
#   u'contains(1997)': False,
#   u'contains(hoped)': False,
#   u'contains(german)': False,
#   u'contains(church)': False,
#   u'contains(18)': False,
#   u'contains(coincidence)': False,
#   u'contains(sketch)': False,
#   u'contains(bugs)': False,
#   u'contains(depp)': False,
#   u'contains(loved)': False,
#   u'contains(based)': False,
#   u'contains(horse)': False,
#   u'contains(williamson)': False,
#   u'contains(lover)': False,
#   u'contains(scott)': False,
#   u'contains(proceedings)': False,
#   u'contains(cameos)': False,
#   u'contains(suspicious)': False,
#   u'contains(stage)': False,
#   u'contains(wrong)': False,
#   u'contains(florida)': False,
#   u'contains(endless)': False,
#   u'contains(school)': False,
#   u'contains(_the)': False,
#   u'contains(terribly)': False,
#   u'contains(shining)': False,
#   u'contains(creature)': False,
#   u'contains(baker)': False,
#   u'contains(marketing)': False,
#   u'contains(food)': False,
#   u'contains(disbelief)': True,
#   u'contains(costumes)': False,
#   u'contains(tight)': False,
#   u'contains(main)': False,
#   u'contains(strictly)': False,
#   u'contains(dropped)': False,
#   u'contains(opportunity)': False,
#   u'contains(payoff)': False,
#   u'contains(chooses)': False,
#   u'contains(depressed)': False,
#   u'contains(enormous)': False,
#   u'contains(frankenstein)': False,
#   u'contains(farrelly)': False,
#   u'contains(laughs)': False,
#   u'contains(concerns)': False,
#   u'contains(kubrick)': False,
#   u'contains(beats)': False,
#   u'contains(recognized)': False,
#   u'contains(superb)': False,
#   u'contains(genre)': False,
#   u'contains(means)': False,
#   u'contains(arrested)': False,
#   u'contains(alcoholic)': False,
#   u'contains(serve)': False,
#   u'contains(cut)': False,
#   u'contains(twenty)': False,
#   u'contains(succeed)': False,
#   u'contains(tunes)': False,
#   u'contains(touching)': False,
#   u'contains(election)': False,
#   u'contains(egypt)': False,
#   u'contains(statement)': False,
#   u'contains(spader)': False,
#   u'contains(powerful)': False,
#   u'contains(term)': False,
#   u'contains(joined)': False,
#   u'contains(campbell)': False,
#   u'contains(newman)': False,
#   u'contains(julie)': False,
#   u'contains(trying)': False,
#   u'contains(homage)': False,
#   u'contains(dry)': False,
#   u'contains(simultaneously)': False,
#   u'contains(aging)': False,
#   u'contains(breaks)': False,
#   u'contains(evening)': False,
#   u'contains(member)': False,
#   u'contains(answers)': False,
#   u'contains(concern)': False,
#   u'contains(comic)': False,
#   u'contains(sappy)': False,
#   u'contains(walks)': False,
#   u'contains(performer)': False,
#   u'contains(compelling)': False,
#   u'contains(appear)': False,
#   u'contains(dressing)': False,
#   u'contains(newspaper)': False,
#   u'contains(starship)': False,
#   u'contains(revolution)': False,
#   u'contains(felt)': False,
#   u'contains(ideal)': False,
#   u'contains(mildly)': False,
#   u'contains(neat)': False,
#   u'contains(vague)': False,
#   u'contains(bird)': False,
#   u'contains(roy)': False,
#   u'contains(brings)': False,
#   u'contains(group)': False,
#   u'contains(brosnan)': False,
#   u'contains(supporting)': False,
#   u'contains(precisely)': False,
#   u'contains(brad)': False,
#   u'contains(runs)': False,
#   u'contains(buddy)': False,
#   u'contains(eight)': False,
#   u'contains(sentimental)': False,
#   u'contains(striking)': False,
#   u'contains(journey)': False,
#   u'contains(combined)': False,
#   u'contains(level)': False,
#   u'contains(finished)': False,
#   u'contains(suzie)': False,
#   u'contains(rising)': False,
#   u'contains(row)': False,
#   u'contains(direct)': False,
#   u'contains(figured)': False,
#   u'contains(patients)': False,
#   u'contains(partner)': False,
#   u'contains(feel)': False,
#   u'contains(unfolds)': False,
#   u'contains(supposedly)': False,
#   u'contains(cop)': False,
#   u'contains(sorts)': False,
#   u'contains(variety)': False,
#   u'contains(wonderfully)': False,
#   u'contains(said)': False,
#   u'contains(performing)': False,
#   u'contains(70s)': False,
#   u'contains(residents)': False,
#   u'contains(agrees)': False,
#   u'contains(am)': False,
#   u'contains(older)': False,
#   u'contains(snake)': False,
#   u'contains(sports)': False,
#   u'contains(romeo)': False,
#   u'contains(quinn)': False,
#   u'contains(miserably)': False,
#   u'contains(delight)': False,
#   u'contains(possibility)': False,
#   u'contains(behavior)': False,
#   u'contains(reveal)': False,
#   u'contains(decides)': False,
#   u'contains(countless)': False,
#   u'contains(join)': False,
#   u'contains(bloody)': False,
#   u'contains(bet)': False,
#   u'contains(georgia)': False,
#   u'contains(population)': False,
#   u'contains(occurs)': False,
#   u'contains(snow)': False,
#   u'contains(noticed)': False,
#   u'contains(need)': False,
#   u'contains(merely)': False,
#   u'contains(racism)': False,
#   u'contains(breathtaking)': False,
#   u'contains(worked)': False,
#   u'contains(canadian)': False,
#   u'contains(holmes)': False,
#   u'contains(move)': False,
#   u'contains(provides)': False,
#   u'contains(sir)': False,
#   u'contains(possibilities)': False,
#   u'contains(placed)': False,
#   u'contains(critique)': False,
#   u'contains(contain)': False,
#   ...},
#  u'neg')

# %%
# training using naive Baysian classifier with a 90/10 split
train_set, test_set = featuresets[200:], featuresets[:200]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (nltk.classify.accuracy(classifier, test_set))
# the accuracy result may vary since we randomized the documents
# Out:
# 0.835

# %%
# show which features of classifier are most informative
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#          contains(worst) = True              neg : pos    =      4.7 : 1.0
#         contains(stupid) = True              neg : pos    =      3.7 : 1.0
#      contains(excellent) = True              pos : neg    =      3.4 : 1.0
#         contains(boring) = True              neg : pos    =      3.4 : 1.0
#      contains(perfectly) = True              pos : neg    =      2.7 : 1.0
#      contains(effective) = True              pos : neg    =      2.6 : 1.0
#      contains(brilliant) = True              pos : neg    =      2.5 : 1.0
#       contains(supposed) = True              neg : pos    =      2.4 : 1.0
#      contains(wonderful) = True              pos : neg    =      2.4 : 1.0
#          contains(solid) = True              pos : neg    =      2.3 : 1.0
#           contains(wars) = True              pos : neg    =      2.3 : 1.0
#             contains(it) = False             neg : pos    =      2.3 : 1.0
#        contains(perfect) = True              pos : neg    =      2.2 : 1.0
#       contains(powerful) = True              pos : neg    =      2.2 : 1.0
#         contains(minute) = True              neg : pos    =      2.2 : 1.0
#         contains(batman) = True              neg : pos    =      2.1 : 1.0
#           contains(poor) = True              neg : pos    =      2.1 : 1.0
#        contains(reality) = True              pos : neg    =      2.1 : 1.0
#          contains(oscar) = True              pos : neg    =      2.1 : 1.0
#         contains(others) = True              pos : neg    =      2.1 : 1.0
#              contains(b) = True              neg : pos    =      2.1 : 1.0
#          contains(harry) = True              neg : pos    =      2.1 : 1.0
#      contains(hilarious) = True              pos : neg    =      2.1 : 1.0
#          contains(worse) = True              neg : pos    =      2.1 : 1.0
#         contains(visual) = True              pos : neg    =      2.1 : 1.0
#           contains(none) = True              neg : pos    =      2.0 : 1.0
#          contains(class) = True              pos : neg    =      2.0 : 1.0
#        contains(history) = True              pos : neg    =      2.0 : 1.0
#      contains(sometimes) = True              pos : neg    =      2.0 : 1.0
#          contains(jokes) = True              neg : pos    =      2.0 : 1.0
